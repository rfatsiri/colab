# %% [markdown]
# <a href="https://colab.research.google.com/github/rfatsiri/colab/blob/main/osmnx_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import osmnx as ox
import matplotlib.pyplot as plt

G = ox.graph_from_place("Surabaya, Indonesia", network_type="drive")

# %%
fig, ax = ox.plot_graph(G)

# %%
import osmnx as ox
import matplotlib.pyplot as plt

Gjava = ox.graph_from_place("Java, Indonesia", network_type="drive")
